# %% [markdown]
# <a href="https://colab.research.google.com/github/KCM2005/Kalenga-Mumba/blob/main/19Feb_RGB_HW.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt
import requests

# %%
url = 'https://blog-assets.thedyrt.com/uploads/2020/02/shutterstock_175711454-1.jpg'
image = np.asarray(Image.open(requests.get(url, stream=True).raw))

# %%
print(image)
# Out:
# [[[104 140 198]
#   [104 140 198]
#   [104 140 198]
#   ...
#   [190 189 220]
#   [189 188 220]
#   [189 188 220]]
#
#  [[104 140 198]
#   [104 140 198]
#   [104 140 198]
#   ...
#   [189 188 219]
#   [188 187 219]
#   [188 187 219]]
#
#  [[105 141 199]
#   [105 141 199]
#   [105 141 199]
#   ...
#   [188 187 218]
#   [187 186 217]
#   [187 186 217]]
#
#  ...
#
#  [[ 30  20  28]
#   [ 33  23  31]
#   [ 39  29  37]
#   ...
#   [ 15  11  28]
#   [ 19  14  36]
#   [ 21  16  39]]
#
#  [[ 41  31  39]
#   [ 41  31  39]
#   [ 43  33  41]
#   ...
#   [ 17  10  28]
#   [ 21  13  37]
#   [ 23  14  41]]
#
#  [[ 51  41  49]
#   [ 50  40  48]
#   [ 49  39  47]
#   ...
#   [ 17  10  28]
#   [ 21  12  39]
#   [ 23  14  43]]]

# %%
plt.imshow(image)

# %%
def example1(image):
  red_photo = np.where(image > 255, 0, 0)
  return red_photo

# %%
 plt.imshow(red_photo)

# %%
def example2(image):
  green_photo = np.where(image > 0, 255, 0)
  return green_photo

# %%
plt.imshow(green_photo)

# %%
def example3(image):
  blue_photo = np.where(image < 0, 0, 255)
  return blue_photo

# %%
plt.imshow(blue_photo)

# %%
def example4(image):
  RG_photo = np.where(image > 178, 230, 0)
  return RG_photo

# %%
plt.imshow(RG_photo)

# %%
def example5(image):
  RB_photo = np.where(image < 195, 0, 230)
  return RB_photo

# %%
plt.imshow(RB_photo)

# %%
def example6(image):
  GB_photo = np.where(image > 0, 200, 15)
  return GB_photo

# %%
plt.imshow(GB_photo)
